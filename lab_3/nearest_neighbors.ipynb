# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neighbors import NearestNeighbors

# %%
X = np.array([
    [2.1, 1.3],
    [1.3, 3.2],
    [2.9, 2.5],
    [2.7, 5.4],
    [3.8, 0.9],
    [7.3, 2.1],
    [4.2, 6.5],
    [3.8, 3.7],
    [2.5, 4.1],
    [3.4, 1.9],
    [5.7, 3.5],
    [6.1, 4.3],
    [5.1, 2.2],
    [6.2, 1.1]
])

# %%
num_neighbors = 5

# %%
input_point = np.array([[4.3, 2.7]])

# %%
knn = NearestNeighbors(
    n_neighbors=num_neighbors,
    algorithm="ball_tree"
)

knn.fit(X)
# Out:
# NearestNeighbors(algorithm='ball_tree')

# %%
distances, indices = knn.kneighbors(input_point)

print("K nearest neighbors:")
print(indices)
print("\nDistances:")
print(distances)
# Out:
# K nearest neighbors:
# [[12  7  9  2 10]]
#
# Distances:
# [[0.94339811 1.11803399 1.20415946 1.41421356 1.61245155]]

# %%
plt.figure()

plt.scatter(
    X[:, 0],
    X[:, 1],
    marker="o",
    s=75,
    color="black"
)

plt.scatter(
    input_point[0, 0],
    input_point[0, 1],
    marker="x",
    s=150,
    color="black"
)

for index in indices[0]:
    plt.scatter(
        X[index, 0],
        X[index, 1],
        marker="o",
        s=200,
        facecolors="none",
        edgecolors="black"
    )

plt.title("K Nearest Neighbors")
plt.show()

# %%
plt.figure()

plt.scatter(
    X[:, 0],
    X[:, 1],
    marker="o",
    s=75,
    color="black"
)

plt.scatter(
    input_point[0, 0],
    input_point[0, 1],
    marker="x",
    s=150,
    color="red"
)

for i in indices[0]:
    plt.plot(
        [input_point[0, 0], X[i, 0]],
        [input_point[0, 1], X[i, 1]],
        "k--"
    )

plt.title("Nearest Neighbor Connections")
plt.show()
