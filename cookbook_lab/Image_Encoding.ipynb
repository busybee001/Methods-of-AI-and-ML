# %%
import numpy as np
from tensorflow.keras.datasets import mnist

(x_train, _), (_, _) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0

compressed = np.mean(x_train, axis=(1,2))

print("Original Images:", x_train.shape)
print("Encoded Vector Shape:", compressed.shape)

print(compressed[:10])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Original Images: (60000, 28, 28)
# Encoded Vector Shape: (60000,)
# [0.13768007 0.15553722 0.0972539  0.08570928 0.11611645 0.14806421
#  0.08826531 0.17940676 0.05439175 0.10956383]
