# %%
# !pip install pyttsx3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 17.3 MB/s  0:00:00a 0:00:010:00:01
# ...
#   Attempting uninstall: pyobjc-core
#     Found existing installation: pyobjc-core 12.1
#     Uninstalling pyobjc-core-12.1:
#       Successfully uninstalled pyobjc-core-12.1
#   Attempting uninstall: pyobjc-framework-Cocoa━━━━━━━━   0/163 [pyobjc-core]
#     Found existing installation: pyobjc-framework-Cocoa 12.1  0/163 [pyobjc-core]
#     Uninstalling pyobjc-framework-Cocoa-12.1:━━━━━   0/163 [pyobjc-core]
#       Successfully uninstalled pyobjc-framework-Cocoa-12.12m  0/163 [pyobjc-core]
#   Attempting uninstall: pyobjc-framework-FSEvents;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━  51/163 [pyobjc-framework-IOBluetooth]
#     Found existing installation: pyobjc-framework-FSEvents 12.137m━━━━━━━━━━━━━━━━━━━━━━━━━━  51/163 [pyobjc-framework-IOBluetooth]
#     Uninstalling pyobjc-framework-FSEvents-12.1:4m╸━━━━━━━━━━━━━━━━━━━━━━━━━━  51/163 [pyobjc-framework-IOBluetooth]
# ...

# %%
import sys
print(sys.executable)
# Out:
# /Users/vikasshukla/.pyenv/versions/3.11.6/bin/python

# %%
import sys
# !{sys.executable} -m pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached pyobjc-12.2-py3-none-any.whl.metadata (26 kB)
# ...
#   Using cached pyobjc_framework_adservices-12.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_adsupport-12.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_apptrackingtransparency-12.2-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached pyobjc_framework_arkit-12.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_accounts-12.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_applescriptkit-12.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_applescriptobjc-12.2-py2.py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached pyobjc_framework_businesschat-12.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_calendarstore-12.2-py2.py3-none-any.whl.metadata (2.8 kB)
# ...

# %%
import pyttsx3
print("pyttsx3 imported successfully")
# Out:
# pyttsx3 imported successfully

# %%
import os

text = "Artificial intelligence is changing the way computers understand speech and language."

print("Input Text:")
print(text)

os.system(f'say "{text}"')
# Out:
# Input Text:
# Artificial intelligence is changing the way computers understand speech and language.
# 0

# %%
engine = pyttsx3.init()

voices = engine.getProperty("voices")

print("Available Voices:")
for i, voice in enumerate(voices):
    print(i, voice.name)
# Out:
# Available Voices:
# 0 Albert
# 1 Alice
# 2 Soumya
# 3 Alva
# 4 Aman
# 5 Amélie
# 6 Amira
# 7 Anna
# 8 Aru
# 9 Bad News
# 10 Bahh
# 11 Bells
# 12 Boing
# 13 Bubbles
# 14 Carmit
# 15 Cellos
# 16 Damayanti
# 17 Daniel
# 18 Daria
# 19 Wobble
# 20 Eddy (German (Germany))
# 21 Eddy (English (UK))
# 22 Eddy (English (US))
# 23 Eddy (Spanish (Spain))
# 24 Eddy (Spanish (Mexico))
# 25 Eddy (Finnish (Finland))
# 26 Eddy (French (Canada))
# 27 Eddy (French (France))
# 28 Eddy (Italian (Italy))
# 29 Eddy (Japanese (Japan))
# 30 Eddy (Korean (South Korea))
# 31 Eddy (Portuguese (Brazil))
# 32 Eddy (Chinese (China mainland))
# 33 Eddy (Chinese (Taiwan))
# 34 Ellen
# 35 Flo (German (Germany))
# 36 Flo (English (UK))
# 37 Flo (English (US))
# 38 Flo (Spanish (Spain))
# 39 Flo (Spanish (Mexico))
# 40 Flo (Finnish (Finland))
# 41 Flo (French (Canada))
# 42 Flo (French (France))
# 43 Flo (Italian (Italy))
# 44 Flo (Japanese (Japan))
# 45 Flo (Korean (South Korea))
# 46 Flo (Portuguese (Brazil))
# ...

# %%
engine.setProperty("rate", 150)
engine.setProperty("volume", 1.0)

output_file = "synthesized_speech.wav"

engine.save_to_file(text, output_file)
engine.runAndWait()

print("Speech file created:", output_file)
# Out:
# Speech file created: synthesized_speech.wav

# %%
from IPython.display import Audio

# %%
Audio("synthesized_speech.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
