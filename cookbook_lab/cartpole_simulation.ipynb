# %%
import random

position = 0

for step in range(10):

    action = random.choice(["LEFT", "RIGHT"])

    if action == "LEFT":
        position -= 1
    else:
        position += 1

    print("Step", step + 1,
          "| Action:", action,
          "| Position:", position)

print("\nSimulation Complete")
# Out:
# Step 1 | Action: LEFT | Position: -1
# Step 2 | Action: LEFT | Position: -2
# Step 3 | Action: LEFT | Position: -3
# Step 4 | Action: LEFT | Position: -4
# Step 5 | Action: LEFT | Position: -5
# Step 6 | Action: LEFT | Position: -6
# Step 7 | Action: RIGHT | Position: -5
# Step 8 | Action: LEFT | Position: -6
# Step 9 | Action: LEFT | Position: -7
# Step 10 | Action: RIGHT | Position: -6
#
# Simulation Complete
