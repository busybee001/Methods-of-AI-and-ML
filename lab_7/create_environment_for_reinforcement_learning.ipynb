# %%
pip install gymnasium pygame
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting pygame
#   Downloading pygame-2.6.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/vikasshukla/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from gymnasium) (1.26.4)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/vikasshukla/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from gymnasium) (4.11.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 7.7 MB/s eta 0:00:00
# Downloading pygame-2.6.1-cp311-cp311-macosx_11_0_arm64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 20.3 MB/s eta 0:00:00MB/s eta 0:00:01:01
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Installing collected packages: farama-notifications, pygame, cloudpickle, gymnasium
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.6 gymnasium-1.3.0 pygame-2.6.1
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: /Users/vikasshukla/.pyenv/versions/3.11.6/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import time

# %%
env = gym.make(
    "CartPole-v1",
    render_mode="human"
)

observation, info = env.reset()

print("Environment Loaded")
# Out:
# Environment Loaded

# %%
for step in range(500):

    # Random action
    action = env.action_space.sample()

    observation, reward, terminated, truncated, info = env.step(action)

    time.sleep(0.05)

    if terminated or truncated:
        print("Episode ended at step:", step)

        # Keep window open
        time.sleep(5)

        break

env.close()
# Out:
# Episode ended at step: 11

# %%
env = gym.make(
    "MountainCar-v0",
    render_mode="human"
)

observation, info = env.reset()

print("Mountain Car Environment Loaded")
# Out:
# Mountain Car Environment Loaded

# %%
for step in range(1000):

    action = env.action_space.sample()

    observation, reward, terminated, truncated, info = env.step(action)

    time.sleep(0.03)

    if terminated or truncated:
        print("Episode finished")

        time.sleep(5)

        break

env.close()
# Out:
# Episode finished
