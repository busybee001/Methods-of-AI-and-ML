# %%
import sys

# !{sys.executable} -m pip install numpy scipy matplotlib SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 29.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: /Users/vikasshukla/.pyenv/versions/3.11.6/bin/python -m pip install --upgrade pip

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

print("Chapter 12 setup completed successfully.")
# Out:
# Chapter 12 setup completed successfully.
