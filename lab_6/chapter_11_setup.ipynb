# %%
import sys

# !{sys.executable} -m pip install pandas matplotlib numpy scikit-learn hmmlearn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: /Users/vikasshukla/.pyenv/versions/3.11.6/bin/python -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Chapter 11 setup completed successfully.")
# Out:
# Chapter 11 setup completed successfully.
