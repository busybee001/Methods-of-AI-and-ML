# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import write

# Output audio file
output_file = "generated_audio.wav"

# Parameters
sampling_freq = 44100
duration = 4

# Generate time axis
t = np.linspace(0, duration,
                int(sampling_freq * duration))

# Generate audio signal
signal = 0.5 * np.sin(2 * np.pi * 587 * t)

# Save WAV file
write(
    output_file,
    sampling_freq,
    (signal * 32767).astype(np.int16)
)

print("Audio file generated successfully.")
print("File name:", output_file)

# Plot signal
plt.figure(figsize=(10, 5))
plt.plot(t[:1000], signal[:1000])
plt.title("Generated Audio Signal")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()
# Out:
# Audio file generated successfully.
# File name: generated_audio.wav
