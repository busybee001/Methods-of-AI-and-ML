# %%
import sys
# !{sys.executable} -m pip install python-constraint
# Out:
# ...
#   Using cached python-constraint-1.4.0.tar.bz2 (18 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python-constraint: filename=python_constraint-1.4.0-py2.py3-none-any.whl size=24058 sha256=fdebf63054563e96ab9b522f0353434795beede98a63ef0e87b1ef4b13cead58
#   Stored in directory: /Users/vikasshukla/Library/Caches/pip/wheels/1e/af/a9/990ae7e6a78319b7d7afaab2d14e7e5ae349d5613db5ae28fd
# Successfully built python-constraint
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: /Users/vikasshukla/.pyenv/versions/3.11.6/bin/python -m pip install --upgrade pip

# %%
from constraint import Problem

# %%
def constraint_unique(john, anna):
    return john != anna

# %%
def constraint_bigger(tom, anna):
    return tom > anna

# %%
def constraint_even_odd(john, patricia):
    return john % 2 != patricia % 2

# %%
variables = ('John', 'Anna', 'Tom', 'Patricia')

# %%
domains = {
    'John': [1, 2, 3],
    'Anna': [1, 2, 3],
    'Tom': [10, 11, 31],
    'Patricia': [1, 2, 3, 4]
}

# %%
problem = Problem()

# %%
print("Solution:\n")

print(problem.getSolution())
# Out:
# Solution:
#
# {'Anna': 3, 'John': 1, 'Patricia': 4, 'Tom': 31}
